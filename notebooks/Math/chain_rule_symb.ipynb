# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sigmoid = lambda x: 1 / (1 + np.exp(-x))
sqare = lambda x: np.power(x,2)

# %%
import sympy as sy

x,y,a,b,c = sy.symbols('x y a b c ')

f1 = x**2 + 2 *x 
f2 = sy.sin(f1)

sy.diff(f2,x)
# Out:
# (2*x + 2)*cos(x**2 + 2*x)

# %%
sy.diff(sy.sin(sy.E**(2*x)), x)
# Out:
# 2*exp(2*x)*cos(exp(2*x))

# %%
sy.diff(1 / (1+sy.exp(-x)), x)
# Out:
# exp(-x)/(1 + exp(-x))**2

# %%
sy.diff(1 / (1+sy.exp(-(x**2))), x)
# Out:
# 2*x*exp(-x**2)/(1 + exp(-x**2))**2

# %%
def f2f1(x):
    # f1 = x**2 f2 = sigmoid(x)  f2f1 = f2(f1(x))
    x = np.array(x)
    return 1 / (1+np.exp(-(x**2)))

def df2f1(x):
    x = np.array(x)
    return (2*x*np.exp(-x**2)) / (1+np.exp(-x**2))**2

# %%
x = np.arange(-3,3,0.1)
y = f2f1(x)
dy = df2f1(x)

#print(x.size, y.size)
plt.plot(x,y)
plt.plot(x,dy)
plt.grid(True)
